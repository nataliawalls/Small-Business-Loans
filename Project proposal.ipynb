# %% [markdown]
# # Project 2 - Small Business Loans
#
# Manager: Sherry
#
# Member: Emerie
#
# Member: Natalia

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/mirbektoktogaraev/should-this-loan-be-approved-or-denied

# %% [markdown]
# Research question(s):
# - What factors tend to cause a loan to be defaulted on?
# - What factors affect how much the loan is for?
# - Build a model to predict which approved loan applications will default on their loan.

# %% [markdown]
# ## Initial responsibilities
#
# ### Sherry
# Look into the factors that cause a loan to be  defaulted on.
#
# ### Emerie
# Analyzing what factors influence how much money is borrowed.
#
# ### Natalia
# Helping with visuals that support factors of how much money is being borrowed and factors that cause a loan to be defaulted on.

# %% [markdown]
# ## Manager's section
#
# The manager should, over several paragraphs, describe the expected challenges for this project. Talk about the parts you think will be difficult (doing the modeling? preparing the data? keeping team members on-task?) and how you plan to address them. Specifically list out goals for yourself in terms of these challenges. I will check in with you throughout the semester on how you are progressing with these goals in order to help you succeed. Talk about why each team member was given each of their duties and responsibilities. Talk about your overall goals for the project. What are the things you are hoping to accomplish for this project to be considered a success? Is it an accuracy goal? Is it being able to explain a complex question in an easy way? Is it to add new insight to an important problem? Be as specific as possible. During your final presentation I will be looking for whether or not you achieved these goals, so they must be clearly defined and not overly broad.

# %% [markdown]
# Approved by Dr. Savala on: XX/XX/XXXX

# %% [markdown]
# I'm really excited to work with my team. The most difficult part of the project will be modeling predictions. The best way to address this issue will be to help each other when an issue occurs. Another difficulty we might face is the amount of time we have to complete this project. I plan to schedule a time we can meet to work together on the project. Also, remind our team to be communicating what we're working on. I didn't want to micromanage the team so we openly talked about what we wanted to work on. The main goal I want to set for this project is to make sure our presentation is cohesive. This can be easily attained and I have full faith that my team can accomplish this goal.
